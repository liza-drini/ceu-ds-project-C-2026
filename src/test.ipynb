# %% [markdown]
# Upload Datasets

# %%
import pandas as pd
rt_df = pd.read_csv('datatata/AggregatedData_AustralianSpeciesOccurrences.csv')
eco_df = pd.read_csv('datatata/Cost.csv')

# %% [markdown]
# Clean data

# %%
eco_df.head()

# %%
rt_df[['year'], ['occurenceCount']] = pd.to_numeric(rt_df[['year'], ['occurrenceCount']])
rt_df = rt_df[rt_df['year'] >= 1960]
rt_df.head()
# Out:
#         year      basisOfRecord                stateTerritory  \
# 826899  1960  HUMAN_OBSERVATION  Australian Capital Territory
# 826900  1960  HUMAN_OBSERVATION  Australian Capital Territory
# 826901  1960  HUMAN_OBSERVATION  Australian Capital Territory
# 826902  1960  HUMAN_OBSERVATION  Australian Capital Territory
# 826903  1960  HUMAN_OBSERVATION  Australian Capital Territory
#
#              ibraRegion imcraRegion forest2018Status forest2013Status  \
# 826899  Australian Alps         NaN           forest           forest
# 826900  Australian Alps         NaN           forest           forest
# 826901  Australian Alps         NaN           forest           forest
# 826902  Australian Alps         NaN           forest           forest
# 826903  Australian Alps         NaN           forest           forest
#
#        capadStatus  epbcStatus griisStatus  \
# 826899          PA  Not listed      Native
# 826900          PA  Not listed      Native
# 826901          PA  Not listed      Native
# 826902          PA  Not listed      Native
# 826903          PA  Not listed      Native
#
#                                                 speciesID  \
# 826899  https://biodiversity.org.au/afd/taxa/1a6f90b8-...
# 826900  https://biodiversity.org.au/afd/taxa/e3103245-...
# 826901   https://id.biodiversity.org.au/node/apni/2887784
# 826902   https://id.biodiversity.org.au/node/apni/2889216
# 826903   https://id.biodiversity.org.au/node/apni/2889349
#
#                       speciesName  occurrenceCount
# 826899  Scythrops novaehollandiae                1
# 826900        Pardalotus striatus                1
# 826901        Micromyrtus ciliata                2
# 826902         Discaria pubescens                2
# 826903         Pimelea ligustrina                1

# %%
rt_df['imcraRegion'].value_counts()

# %%
rt_df['imcraRegion'].nunique()
