# %% [markdown]
# ##

# %% [markdown]
# ## Experiments

# %%
import pandas as pd

# %%
eco_df = pd.read_csv('../datasets/eco_df_clean.csv')
cats =  pd.read_csv('../datasets/Cat_only_rt.csv')



sheeps_cats = pd.read_csv('../datasets/farm_cat.csv')

# %%
git stash
# Out:
#   Cell In[1], line 1
#     git stash
#         ^
# SyntaxError: invalid syntax
