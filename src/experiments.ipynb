# %% [markdown]
# ##

# %% [markdown]
# # Ben make your model here pls

# %%
import pandas as pd
import statsmodels.api as sm

df = pd.read_csv('../datasets/Cat_only_rt.csv')

# %% [markdown]
# # Ben code cleaning

# %% [markdown]
# #Stat Analysis

# %%
# Statistical analysis - Liza
merged = df.groupby(['year', 'ibraRegion'])['occurrenceCount'].sum().reset_index()


for state in merged['ibraRegion'].unique():
    state_df = merged[merged['ibraRegion'] == state]

    X = sm.add_constant(state_df['year'])
    y = state_df['occurrenceCount']

    model = sm.OLS(y, X).fit()
    print(f"\n{state}")
    print(model.summary())
# Out:
# South East Corner
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.367
# Method:                 Least Squares   F-statistic:                     33.98
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):           2.88e-07
# Time:                        09:22:32   Log-Likelihood:                -295.46
# No. Observations:                  58   AIC:                             594.9
# Df Residuals:                      56   BIC:                             599.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3576.1540    619.901     -5.769      0.000   -4817.965   -2334.343
# year           1.8127      0.311      5.829      0.000       1.190       2.436
# ==============================================================================
# Omnibus:                       18.081   Durbin-Watson:                   1.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.258
# Skew:                           1.174   Prob(JB):                     5.40e-06
# Kurtosis:                       5.128   Cond. No.                     2.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# South Eastern Highlands
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.414
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     39.48
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):           5.24e-08
# Time:                        09:22:32   Log-Likelihood:                -312.49
# No. Observations:                  58   AIC:                             629.0
# Df Residuals:                      56   BIC:                             633.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5168.9938    830.051     -6.227      0.000   -6831.785   -3506.203
# year           2.6164      0.416      6.283      0.000       1.782       3.451
# ==============================================================================
# Omnibus:                       33.540   Durbin-Watson:                   0.606
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.263
# Skew:                           1.751   Prob(JB):                     2.26e-18
# Kurtosis:                       7.622   Cond. No.                     2.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# South Eastern Queensland
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.204
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     13.57
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):           0.000540
# Time:                        09:22:32   Log-Likelihood:                -234.10
# No. Observations:                  55   AIC:                             472.2
# Df Residuals:                      53   BIC:                             476.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1020.2929    281.258     -3.628      0.001   -1584.425    -456.161
# year           0.5195      0.141      3.684      0.001       0.237       0.802
# ==============================================================================
# Omnibus:                       27.482   Durbin-Watson:                   1.442
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.078
# Skew:                           1.705   Prob(JB):                     9.87e-11
# Kurtosis:                       5.912   Cond. No.                     2.39e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.39e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Daly Basin
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     1.289
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.278
# Time:                        09:22:32   Log-Likelihood:                -41.363
# No. Observations:                  14   AIC:                             86.73
# Df Residuals:                      12   BIC:                             88.00
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -189.3149    169.561     -1.117      0.286    -558.756     180.127
# year           0.0962      0.085      1.135      0.278      -0.088       0.281
# ==============================================================================
# Omnibus:                       13.096   Durbin-Watson:                   1.474
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                8.790
# Skew:                           1.719   Prob(JB):                       0.0123
# Kurtosis:                       4.803   Cond. No.                     2.53e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.53e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Murray Darling Depression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     12.16
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):            0.00104
# Time:                        09:22:32   Log-Likelihood:                -256.77
# No. Observations:                  51   AIC:                             517.5
# Df Residuals:                      49   BIC:                             521.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2200.0051    635.963     -3.459      0.001   -3478.020    -921.990
# year           1.1118      0.319      3.488      0.001       0.471       1.753
# ==============================================================================
# Omnibus:                       43.067   Durbin-Watson:                   0.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              139.090
# Skew:                           2.364   Prob(JB):                     6.27e-31
# Kurtosis:                       9.565   Cond. No.                     2.39e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.39e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Riverina
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.209
# Method:                 Least Squares   F-statistic:                     11.54
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):            0.00158
# Time:                        09:22:33   Log-Likelihood:                -139.40
# No. Observations:                  41   AIC:                             282.8
# Df Residuals:                      39   BIC:                             286.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -503.3595    149.927     -3.357      0.002    -806.615    -200.104
# year           0.2549      0.075      3.397      0.002       0.103       0.407
# ==============================================================================
# Omnibus:                       60.366   Durbin-Watson:                   2.125
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              482.995
# Skew:                           3.496   Prob(JB):                    1.31e-105
# Kurtosis:                      18.292   Cond. No.                     2.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Mulga Lands
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.149
# Model:                            OLS   Adj. R-squared:                  0.110
# Method:                 Least Squares   F-statistic:                     3.841
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):             0.0628
# Time:                        09:22:33   Log-Likelihood:                -80.161
# No. Observations:                  24   AIC:                             164.3
# Df Residuals:                      22   BIC:                             166.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -368.4061    190.922     -1.930      0.067    -764.355      27.543
# year           0.1873      0.096      1.960      0.063      -0.011       0.385
# ==============================================================================
# Omnibus:                       24.773   Durbin-Watson:                   1.500
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.582
# Skew:                           2.075   Prob(JB):                     2.54e-09
# Kurtosis:                       7.729   Cond. No.                     2.62e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.62e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Pilbara
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.696
# Model:                            OLS   Adj. R-squared:                  0.544
# Method:                 Least Squares   F-statistic:                     4.580
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.166
# Time:                        09:22:33   Log-Likelihood:                -1.9076
# No. Observations:                   4   AIC:                             7.815
# Df Residuals:                       2   BIC:                             6.588
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -44.5429     21.749     -2.048      0.177    -138.123      49.037
# year           0.0232      0.011      2.140      0.166      -0.023       0.070
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.744
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.568
# Skew:                           0.755   Prob(JB):                        0.753
# Kurtosis:                       1.940   Cond. No.                     1.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Central Ranges
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.091
# Method:                 Least Squares   F-statistic:                   0.08590
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.775
# Time:                        09:22:33   Log-Likelihood:                -25.252
# No. Observations:                  12   AIC:                             54.50
# Df Residuals:                      10   BIC:                             55.47
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -21.3969     80.401     -0.266      0.796    -200.541     157.748
# year           0.0118      0.040      0.293      0.775      -0.078       0.102
# ==============================================================================
# Omnibus:                       18.274   Durbin-Watson:                   1.620
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               13.071
# Skew:                           2.009   Prob(JB):                      0.00145
# Kurtosis:                       6.163   Cond. No.                     2.55e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Eyre Yorke Block
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.116
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     3.137
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):             0.0893
# Time:                        09:22:33   Log-Likelihood:                -112.89
# No. Observations:                  26   AIC:                             229.8
# Df Residuals:                      24   BIC:                             232.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -897.7680    513.683     -1.748      0.093   -1957.958     162.422
# year           0.4541      0.256      1.771      0.089      -0.075       0.983
# ==============================================================================
# Omnibus:                       18.387   Durbin-Watson:                   1.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.614
# Skew:                           1.827   Prob(JB):                     3.34e-05
# Kurtosis:                       5.382   Cond. No.                     2.71e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.71e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# c:\Users\d\Miniconda3\envs\ml\lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=14 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# c:\Users\d\Miniconda3\envs\ml\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# c:\Users\d\Miniconda3\envs\ml\lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=12 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# c:\Users\d\Miniconda3\envs\ml\lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=10 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# Flinders Lofty Block
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.248
# Model:                            OLS   Adj. R-squared:                  0.229
# Method:                 Least Squares   F-statistic:                     12.86
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):           0.000922
# Time:                        09:22:33   Log-Likelihood:                -207.75
# No. Observations:                  41   AIC:                             419.5
# Df Residuals:                      39   BIC:                             422.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2587.1973    728.367     -3.552      0.001   -4060.459   -1113.935
# year           1.3082      0.365      3.586      0.001       0.570       2.046
# ==============================================================================
# Omnibus:                       28.493   Durbin-Watson:                   1.747
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.286
# Skew:                           1.890   Prob(JB):                     5.99e-13
# Kurtosis:                       7.320   Cond. No.                     2.37e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.37e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Sydney Basin
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     31.93
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):           9.05e-07
# Time:                        09:22:33   Log-Likelihood:                -285.77
# No. Observations:                  49   AIC:                             575.5
# Df Residuals:                      47   BIC:                             579.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -8656.3734   1544.059     -5.606      0.000   -1.18e+04   -5550.128
# year           4.3691      0.773      5.651      0.000       2.814       5.925
# ==============================================================================
# Omnibus:                       39.537   Durbin-Watson:                   0.662
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.400
# Skew:                           2.260   Prob(JB):                     3.91e-25
# Kurtosis:                       8.884   Cond. No.                     2.56e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.56e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Brigalow Belt South
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.310
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     19.73
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):           5.95e-05
# Time:                        09:22:33   Log-Likelihood:                -251.86
# No. Observations:                  46   AIC:                             507.7
# Df Residuals:                      44   BIC:                             511.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4939.0795   1119.606     -4.411      0.000   -7195.497   -2682.662
# year           2.4887      0.560      4.441      0.000       1.359       3.618
# ==============================================================================
# Omnibus:                       30.663   Durbin-Watson:                   0.454
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.387
# Skew:                           1.919   Prob(JB):                     1.72e-14
# Kurtosis:                       7.282   Cond. No.                     2.57e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.57e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# MacDonnell Ranges
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     2.553
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.121
# Time:                        09:22:33   Log-Likelihood:                -123.92
# No. Observations:                  30   AIC:                             251.8
# Df Residuals:                      28   BIC:                             254.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -804.9259    509.308     -1.580      0.125   -1848.196     238.345
# year           0.4077      0.255      1.598      0.121      -0.115       0.930
# ==============================================================================
# Omnibus:                       44.577   Durbin-Watson:                   2.267
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              187.255
# Skew:                           3.044   Prob(JB):                     2.18e-41
# Kurtosis:                      13.618   Cond. No.                     3.57e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.57e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Nullarbor
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.115
# Method:                 Least Squares   F-statistic:                   0.06899
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.799
# Time:                        09:22:33   Log-Likelihood:                -32.496
# No. Observations:                  10   AIC:                             68.99
# Df Residuals:                       8   BIC:                             69.60
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         76.1406    272.752      0.279      0.787    -552.826     705.107
# year          -0.0359      0.137     -0.263      0.799      -0.351       0.279
# ==============================================================================
# Omnibus:                       17.532   Durbin-Watson:                   2.366
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.737
# Skew:                           1.999   Prob(JB):                      0.00768
# Kurtosis:                       5.717   Cond. No.                     2.47e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.47e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Southern Volcanic Plain
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.109
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     6.011
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):             0.0178
# Time:                        09:22:33   Log-Likelihood:                -179.21
# No. Observations:                  51   AIC:                             362.4
# Df Residuals:                      49   BIC:                             366.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -363.5395    151.664     -2.397      0.020    -668.320     -58.759
# year           0.1862      0.076      2.452      0.018       0.034       0.339
# ==============================================================================
# Omnibus:                       39.266   Durbin-Watson:                   1.546
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              109.728
# Skew:                           2.199   Prob(JB):                     1.49e-24
# Kurtosis:                       8.683   Cond. No.                     2.61e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.61e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Burt Plain
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.307
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     4.869
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):             0.0495
# Time:                        09:22:33   Log-Likelihood:                -41.334
# No. Observations:                  13   AIC:                             86.67
# Df Residuals:                      11   BIC:                             87.80
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -603.5928    276.621     -2.182      0.052   -1212.431       5.245
# year           0.3061      0.139      2.207      0.050       0.001       0.611
# ==============================================================================
# Omnibus:                        2.164   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.339   Jarque-Bera (JB):                0.975
# Skew:                           0.671   Prob(JB):                        0.614
# Kurtosis:                       3.003   Cond. No.                     3.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Davenport Murchison Ranges
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     1.209
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.292
# Time:                        09:22:33   Log-Likelihood:                -27.536
# No. Observations:                  15   AIC:                             59.07
# Df Residuals:                      13   BIC:                             60.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         68.0627     60.210      1.130      0.279     -62.013     198.139
# year          -0.0333      0.030     -1.099      0.292      -0.099       0.032
# ==============================================================================
# Omnibus:                       14.890   Durbin-Watson:                   1.717
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               11.317
# Skew:                           1.745   Prob(JB):                      0.00349
# Kurtosis:                       5.436   Cond. No.                     2.85e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.85e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Finke
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.149
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                     3.143
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):             0.0932
# Time:                        09:22:33   Log-Likelihood:                -55.919
# No. Observations:                  20   AIC:                             115.8
# Df Residuals:                      18   BIC:                             117.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -246.8072    141.720     -1.742      0.099    -544.550      50.936
# year           0.1260      0.071      1.773      0.093      -0.023       0.275
# ==============================================================================
# Omnibus:                        1.747   Durbin-Watson:                   1.112
# Prob(Omnibus):                  0.418   Jarque-Bera (JB):                1.481
# Skew:                           0.595   Prob(JB):                        0.477
# Kurtosis:                       2.399   Cond. No.                     3.03e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.03e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Simpson Strzelecki Dunefields
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.031
# Method:                 Least Squares   F-statistic:                    0.1519
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.700
# Time:                        09:22:33   Log-Likelihood:                -122.53
# No. Observations:                  29   AIC:                             249.1
# Df Residuals:                      27   BIC:                             251.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        187.4984    457.367      0.410      0.685    -750.941    1125.938
# year          -0.0891      0.229     -0.390      0.700      -0.558       0.380
# ==============================================================================
# Omnibus:                       39.574   Durbin-Watson:                   2.310
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              121.030
# Skew:                           2.867   Prob(JB):                     5.23e-27
# Kurtosis:                      11.203   Cond. No.                     2.87e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.87e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Victorian Midlands
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     3.381
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):             0.0724
# Time:                        09:22:33   Log-Likelihood:                -248.69
# No. Observations:                  48   AIC:                             501.4
# Df Residuals:                      46   BIC:                             505.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1461.5966    801.799     -1.823      0.075   -3075.534     152.341
# year           0.7383      0.402      1.839      0.072      -0.070       1.547
# ==============================================================================
# Omnibus:                      101.683   Durbin-Watson:                   2.101
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3143.288
# Skew:                           6.096   Prob(JB):                         0.00
# Kurtosis:                      40.723   Cond. No.                     2.52e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.52e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# c:\Users\d\Miniconda3\envs\ml\lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=13 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# c:\Users\d\Miniconda3\envs\ml\lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=15 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# c:\Users\d\Miniconda3\envs\ml\lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=15 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# Kanmantoo
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.110
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     3.325
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):             0.0793
# Time:                        09:22:33   Log-Likelihood:                -174.77
# No. Observations:                  29   AIC:                             353.5
# Df Residuals:                      27   BIC:                             356.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4201.7465   2323.726     -1.808      0.082   -8969.639     566.146
# year           2.1188      1.162      1.823      0.079      -0.266       4.503
# ==============================================================================
# Omnibus:                       61.841   Durbin-Watson:                   2.195
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              536.705
# Skew:                           4.346   Prob(JB):                    2.86e-117
# Kurtosis:                      22.199   Cond. No.                     2.41e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.41e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Mitchell Grass Downs
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.110
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     3.584
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):             0.0684
# Time:                        09:22:33   Log-Likelihood:                -83.833
# No. Observations:                  31   AIC:                             171.7
# Df Residuals:                      29   BIC:                             174.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -168.9318     91.468     -1.847      0.075    -356.004      18.141
# year           0.0866      0.046      1.893      0.068      -0.007       0.180
# ==============================================================================
# Omnibus:                       14.708   Durbin-Watson:                   2.317
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.424
# Skew:                           1.410   Prob(JB):                     0.000447
# Kurtosis:                       4.996   Cond. No.                     2.72e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# NSW South Western Slopes
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.353
# Model:                            OLS   Adj. R-squared:                  0.337
# Method:                 Least Squares   F-statistic:                     21.82
# ...
# const        184.1255    220.758      0.834      0.442    -383.350     751.601
# year          -0.0906      0.110     -0.822      0.448      -0.374       0.193
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.792
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.092
# Skew:                           0.924   Prob(JB):                        0.579
# Kurtosis:                       2.424   Cond. No.                     4.32e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Tasmanian Southern Ranges
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):                nan
# Time:                        09:22:34   Log-Likelihood:                 54.247
# No. Observations:                   2   AIC:                            -104.5
# Df Residuals:                       0   BIC:                            -107.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -961.1379        inf         -0        nan         nan         nan
# year           0.4828        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.040
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.333
# Skew:                           0.000   Prob(JB):                        0.846
# Kurtosis:                       1.000   Cond. No.                     2.78e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.78e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# King
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.149
# Model:                            OLS   Adj. R-squared:                 -0.277
# Method:                 Least Squares   F-statistic:                    0.3498
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.614
# Time:                        09:22:34   Log-Likelihood:                -12.562
# No. Observations:                   4   AIC:                             29.12
# Df Residuals:                       2   BIC:                             27.90
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -429.9071    734.467     -0.585      0.618   -3590.064    2730.250
# year           0.2156      0.365      0.591      0.614      -1.353       1.784
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.733
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.547
# Skew:                           0.715   Prob(JB):                        0.761
# Kurtosis:                       1.889   Cond. No.                     3.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Arnhem Coast
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                 -0.143
# Method:                 Least Squares   F-statistic:                    0.2505
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.638
# Time:                        09:22:34   Log-Likelihood:                -12.528
# No. Observations:                   7   AIC:                             29.06
# Df Residuals:                       5   BIC:                             28.95
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         98.2032    191.658      0.512      0.630    -394.470     590.877
# year          -0.0477      0.095     -0.500      0.638      -0.293       0.197
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.163
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.934
# Skew:                           0.864   Prob(JB):                        0.627
# Kurtosis:                       2.536   Cond. No.                     5.95e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.95e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Tasmanian South East
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                 -0.204
# Method:                 Least Squares   F-statistic:                    0.1544
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.714
# Time:                        09:22:34   Log-Likelihood:                -23.389
# No. Observations:                   6   AIC:                             50.78
# Df Residuals:                       4   BIC:                             50.36
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -716.5468   1844.911     -0.388      0.718   -5838.842    4405.748
# year           0.3597      0.916      0.393      0.714      -2.182       2.902
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.478
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.203
# Skew:                           1.075   Prob(JB):                        0.548
# Kurtosis:                       2.562   Cond. No.                     6.23e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.23e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Yalgoo
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                 -0.109
# Method:                 Least Squares   F-statistic:                    0.7057
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.489
# Time:                        09:22:34   Log-Likelihood:                -7.0485
# No. Observations:                   4   AIC:                             18.10
# Df Residuals:                       2   BIC:                             16.87
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        421.2692    498.794      0.845      0.487   -1724.868    2567.407
# year          -0.2077      0.247     -0.840      0.489      -1.271       0.856
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.259
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.306
# Skew:                          -0.140   Prob(JB):                        0.858
# Kurtosis:                       1.674   Cond. No.                     1.01e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Carnarvon
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     3.457
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.160
# Time:                        09:22:34   Log-Likelihood:                -10.994
# No. Observations:                   5   AIC:                             25.99
# Df Residuals:                       3   BIC:                             25.21
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1574.4513    845.383      1.862      0.159   -1115.933    4264.836
# year          -0.7788      0.419     -1.859      0.160      -2.112       0.554
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.102
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.277
# Skew:                          -0.291   Prob(JB):                        0.871
# Kurtosis:                       2.004   Cond. No.                     1.35e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Ben Lomond
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        occurrenceCount   R-squared:                       0.231
# Model:                            OLS   Adj. R-squared:                 -0.154
# Method:                 Least Squares   F-statistic:                    0.6006
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):              0.519
# Time:                        09:22:34   Log-Likelihood:                -10.656
# No. Observations:                   4   AIC:                             25.31
# Df Residuals:                       2   BIC:                             24.09
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1430.4138   1840.295      0.777      0.518   -6487.735    9348.563
# year          -0.7069      0.912     -0.775      0.519      -4.632       3.218
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.129
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.619
# Skew:                           0.830   Prob(JB):                        0.734
# Kurtosis:                       2.021   Cond. No.                     1.51e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Central Kimberley
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 13
#      11 model = sm.OLS(y, X).fit()
#      12 print(f"\n{state}")
# ---> 13 print(model.summary())
#
# File c:\Users\d\Miniconda3\envs\ml\lib\site-packages\statsmodels\regression\linear_model.py:2742, in RegressionResults.summary(self, yname, xname, title, alpha, slim)
#    2739 alpha = float_like(alpha, "alpha", optional=False)
#    2740 slim = bool_like(slim, "slim", optional=False, strict=True)
# -> 2742 jb, jbpv, skew, kurtosis = jarque_bera(self.wresid)
#    2743 omni, omnipv = omni_normtest(self.wresid)
#    2745 eigvals = self.eigenvals
#
# File c:\Users\d\Miniconda3\envs\ml\lib\site-packages\statsmodels\stats\stattools.py:123, in jarque_bera(resids, axis)
#     121 resids = np.atleast_1d(np.asarray(resids, dtype=float))
#     122 if resids.size < 2:
# --> 123     raise ValueError("resids must contain at least 2 elements")
#     124 # Calculate residual skewness and kurtosis
#     125 skew = stats.skew(resids, axis=axis)
#
# ValueError: resids must contain at least 2 elements
