# %% [markdown]
# ## Cleaning dataset

# %%
import pandas as pd
rt_df = pd.read_csv('../datasets/Cat_only_rt.csv')

# %%
rt_df.head()
# Out:
#    Unnamed: 0  year      basisOfRecord   stateTerritory  \
# 0        2902  1900  HUMAN_OBSERVATION  New South Wales
# 1        5093  1900  HUMAN_OBSERVATION  South Australia
# 2        5592  1900  HUMAN_OBSERVATION  South Australia
# 3       33768  1903  HUMAN_OBSERVATION       Queensland
# 4      114291  1911  HUMAN_OBSERVATION  New South Wales
#
#                 ibraRegion imcraRegion forest2018Status forest2013Status  \
# 0  South Eastern Highlands         NaN           forest       non-forest
# 1         Eyre Yorke Block         NaN       non-forest       non-forest
# 2                Kanmantoo         NaN       non-forest       non-forest
# 3      Brigalow Belt South         NaN       non-forest       non-forest
# 4          NSW North Coast         NaN       non-forest       non-forest
#
#      capadStatus  epbcStatus griisStatus  \
# 0  not protected  Not listed    Invasive
# 1             PA  Not listed    Invasive
# 2             PA  Not listed    Invasive
# 3  not protected  Not listed    Invasive
# 4             PA  Not listed    Invasive
#
#                                            speciesID  speciesName  \
# 0  https://biodiversity.org.au/afd/taxa/7de6b16a-...  Felis catus
# 1  https://biodiversity.org.au/afd/taxa/7de6b16a-...  Felis catus
# 2  https://biodiversity.org.au/afd/taxa/7de6b16a-...  Felis catus
# 3  https://biodiversity.org.au/afd/taxa/7de6b16a-...  Felis catus
# 4  https://biodiversity.org.au/afd/taxa/7de6b16a-...  Felis catus
#
#    occurrenceCount
# 0                1
# 1                3
# 2                1
# 3                1
# 4                2

# %%
rt_df.dtypes
# Out:
# Unnamed: 0           int64
# year                 int64
# basisOfRecord       object
# stateTerritory      object
# ibraRegion          object
# imcraRegion         object
# forest2018Status    object
# forest2013Status    object
# capadStatus         object
# epbcStatus          object
# griisStatus         object
# speciesID           object
# speciesName         object
# occurrenceCount      int64
# dtype: object

# %%
#to drop: griisStatuts, epbcStatus, speciesID, basisOfRecord, imcraRegion

# %%
rt_df = rt_df.drop(columns = ['griisStatus', 'epbcStatus', 'speciesID', 'basisOfRecord', 'imcraRegion'])

# %%
rt_df = rt_df[rt_df['year'] > 1959]

# %%
rt_df
# Out:
#       Unnamed: 0  year                stateTerritory  \
# 26        827338  1960               New South Wales
# 27        827397  1960               New South Wales
# 28        827587  1960               New South Wales
# 29        838813  1960  Australian Capital Territory
# 30        885133  1961            Northern Territory
# ...          ...   ...                           ...
# 5092    11617331  2022                           NaN
# 5093    11617334  2022                           NaN
# 5094    11617335  2022                           NaN
# 5095    11617336  2022                           NaN
# 5096    11617339  2022                           NaN
#
#                     ibraRegion forest2018Status forest2013Status  \
# 26           South East Corner           forest           forest
# 27     South Eastern Highlands           forest       non-forest
# 28    South Eastern Queensland           forest           forest
# 29     South Eastern Highlands       non-forest       non-forest
# 30                  Daly Basin           forest       non-forest
# ...                        ...              ...              ...
# 5092                       NaN       non-forest       non-forest
# 5093                       NaN       non-forest       non-forest
# 5094                       NaN       non-forest       non-forest
# 5095                       NaN       non-forest       non-forest
# 5096                       NaN       non-forest       non-forest
#
#         capadStatus  speciesName  occurrenceCount
# 26    not protected  Felis catus                3
# 27    not protected  Felis catus                1
# 28    not protected  Felis catus                1
# 29    not protected  Felis catus                1
# 30    not protected  Felis catus                1
# ...             ...          ...              ...
# 5092  not protected  Felis catus                2
# 5093             PA  Felis catus                4
# 5094  not protected  Felis catus                2
# 5095             PA  Felis catus                5
# 5096  not protected  Felis catus                2
#
# [5071 rows x 9 columns]

# %% [markdown]
# ## Something else
